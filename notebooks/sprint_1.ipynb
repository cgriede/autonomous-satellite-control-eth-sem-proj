# %% [markdown]
# # Sprint Goals
# - show video of satellite orbiting (2d)
# - make the satellite move at max speed in 1 direction constantly
#
# # Sprint Simplifications (to achieve goal)
# - Start from a simplified model first and add complexity iteratively.
# - Model Earth as a perfect sphere.
# - Model clouds as opaque/non-see-through blocks or segments.
# - Begin with realistic control boundaries: provide target orientation vectors and let OBC/AOCS execute low-level control.
# - Keep direct neural-network low-level actuation as an optional later extension if time allows.
